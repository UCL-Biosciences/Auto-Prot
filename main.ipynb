# %% [markdown]
# # Generate Proteomics Report
# Generate common proteomics outputs, save to file and combine in a report.
#
# Inputs must be protein abundance file and metadata, as specified below and in the github README.

# %%
## Import libraries
import os

# %%
## Import functions
# Functions are saved in separate files and imported here
# Separated by module
# More detail in relevant files and on github.
import utils.check_env as env
import utils.data_processing as dp
import utils.analysis as an
#import utils.visualisation as vis

# %%
def main():
    """
    Main script to run the complete data analysis pipeline.
    """
    # Check environment
    if not "VSCODE_PID" in os.environ:
        env.compare_envs()

    # File paths
    # getting repo dir automatically is useful as should mean we don't need to specify
    # machine-specific paths and code should run on different users' machines
    REPO_ROOT = env.get_repo_root()

    # File path to the dataset
    proteinDataPath = os.path.join(REPO_ROOT, 'input/data/proteindata.csv')
    metadataPath = os.path.join(REPO_ROOT, 'input/data/metadata.csv')
    outPath = os.path.join(REPO_ROOT, 'output')
    json_out = os.path.join(REPO_ROOT, 'output/data/data_for_report.json')
    
    # Create the output directory
    dp.make_outdir(outPath)

    # Data processing
    print("Loading and processing data...")
    # metadata
    metadata = dp.preprocess_data(file_path=metadataPath,
                                  json_out=json_out,
                                  outPath = outPath)
    #dp.validate_metadata(metadata)

    # protein abundance data
    df_protAbundance, df_protAbundance_standardised = dp.preprocess_data(file_path=proteinDataPath,
                                                                         metadata=metadata,
                                                                         json_out=json_out,
                                                                         outPath = outPath)    
    #dp.validate_proteindata(df_protAbundance, metadata)

    print("Data loaded and processed...")

    # Analysis
    print("Running analysis...")
    analysis_results = an.run_analysis(df = df_protAbundance,
                                        df_standardised = df_protAbundance_standardised,
                                        metadata = metadata,
                                        json_out=json_out,
                                        output_dir = outPath)
    print("Analysis complete.")


    # Visualisation
    #print("Generating visualizations...")
    #vis.generate_plots(analysis_results)

    # Reporting
    #print("Generating report...")
    #rep.generate_report(data, analysis_results)

    #print("Pipeline completed successfully!")

# %%
if __name__ == "__main__":
    main()
# Out:
# Directory '/Users/Chimz/Library/CloudStorage/OneDrive-UniversityCollegeLondon/Projects/inProgress/04_DataSci_Projects/00_Project_Tracker/05_Auto_Proteomics/Proteomics/01_auto_analysis/02_generate_report/05-Auto-Prot/output' created successfully.
# Loading and processing data...
# Error loading data: [Errno 2] No such file or directory: '/Users/Chimz/Library/CloudStorage/OneDrive-UniversityCollegeLondon/Projects/inProgress/04_DataSci_Projects/00_Project_Tracker/05_Auto_Proteomics/Proteomics/01_auto_analysis/02_generate_report/05-Auto-Prot/data/metadata.csv'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[3], line 26, in main()
#      24 print("Loading and processing data...")
#      25 # metadata
# ---> 26 metadata = dp.preprocess_data(file_path=metadataPath,
#      27                               json_out=json_out,
#      28                               outPath = outPath)
#      29 #dp.validate_metadata(metadata)
#      30
#      31 # protein abundance data
#      32 df_protAbundance, df_protAbundance_standardised = dp.preprocess_data(file_path=proteinDataPath,
#      33                                                                      metadata=metadata,
#      34                                                                      json_out=json_out,
#      35                                                                      outPath = outPath)
#
# File ~/Library/CloudStorage/OneDrive-UniversityCollegeLondon/Projects/inProgress/04_DataSci_Projects/00_Project_Tracker/05_Auto_Proteomics/Proteomics/01_auto_analysis/02_generate_report/05-Auto-Prot/utils/data_processing.py:141, in preprocess_data(file_path, metadata, json_out, outPath)
#     134     #     # Clean data with or without metadata
#     135     #     if metadata is None:
#     136     #         df = clean_data(df, file_path = file_path)
#     137     #     else:
#     138     #         df, row_nan_count = clean_data(df, file_path = file_path, metadata=metadata)
#     140     if 'metadata' in file_path:
# --> 141         df = clean_data(df, file_path = file_path)
#     142 #### df['protein_abundance_name'] = df['protein_abundance_name'].str.lower().str.replace(' ', '_')
#     143
#     144         # generate some info to go into html report
#     145         # Compute treatment-wise sample counts
#     146         treatment_counts = df['treatment'].value_counts().to_dict()
#
# File ~/Library/CloudStorage/OneDrive-UniversityCollegeLondon/Projects/inProgress/04_DataSci_Projects/00_Project_Tracker/05_Auto_Proteomics/Proteomics/01_auto_analysis/02_generate_report/05-Auto-Prot/utils/data_processing.py:77, in clean_data(df, file_path, metadata)
#      61 """
#      62 Perform basic cleaning on the data: first filter protein data to include only protein abundance cols
#      63 Then drop duplicates and NAs
#    (...)
#      74
#      75 """
#      76 if 'metadata' in file_path:
# ---> 77     df['protein_abundance_name'] = df['protein_abundance_name'].str.lower().str.replace(' ', '_')
#      78     df['sample_rep'] = (df['sample_id'] + '_' + df['replicate'].astype(str) )
#      79 if 'proteindata' in file_path:
#
# TypeError: 'NoneType' object is not subscriptable
